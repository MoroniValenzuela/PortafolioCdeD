# %% [markdown]
# # Prácticas de Computer Vision

# %%
# Establecemos credenciales 
key = 'fdaf41030f9140a3a3448915ef8c78bb'
endpoint='https://cv-dr-lab1618.cognitiveservices.azure.com/'

# %%
# conectamos con azure 

from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

client=ComputerVisionClient(endpoint,CognitiveServicesCredentials(key))

# %%
import Vision
import os

import matplotlib

# obtenemos la imagen

image_path = '../data/vision/store-camera-1.jpg'

image_stream = open(image_path, "rb")
description = client.describe_image_in_stream(image_stream)
print(description)

Vision.show_image_caption(image_path, description)
# Out:
# {'additional_properties': {}, 'tags': ['text', 'person', 'woman', 'store', 'shop'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x0000018E6BD881F0>], 'request_id': '6193b0e4-8224-4cee-a7cb-1fd944de170e', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x0000018E6BD3AF80>, 'model_version': '2021-05-01'}

# %%
image_path = '../data/vision/store-camera-2.jpg'
image_stream = open(image_path,"rb")
description = client.describe_image_in_stream(image_stream)

Vision.show_image_caption(image_path, description)

# %%
image_path = '../data/vision/store-camera-1.jpg'

features = ['Description', 'Adult', 'Faces','Objects', 'Tags' ]

image_stream = open(image_path, "rb" )

description = client.describe_image_in_stream(image_stream, visual_features = features )

Vision.show_image_caption(image_path, description)

# %%
image_path = '../data/vision/store-camera-1.jpg'

features = ['Description', 'Adult', 'Faces','Objects', 'Tags' ]

image_stream = open(image_path, "rb" )

analysis = client.analyze_image_in_stream(image_stream, visual_features = features )

Vision.show_image_analysis(image_path, analysis)

# %% [markdown]
# ## Face API
# !pip install azure-cognitiveservices-vision-face

# %%
# %pip install azure-cognitiveservices-vision-face
# Out:
# ...
#      -------------------------------------- 67.7/67.7 kB 229.7 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
key = '549eba23dcbe459dbc8de25e89c448ba'
endpoint = 'https://cv-dr1618face.cognitiveservices.azure.com/'

# conectamos con azure 

from azure.cognitiveservices.vision.face import FaceClient
from msrest.authentication import CognitiveServicesCredentials

client=FaceClient(endpoint,CognitiveServicesCredentials(key))

# %%
import faces
import os
import matplotlib_inline

# %%
image_path = '../data/vision/store-camera-2.jpg'
image_stream = open(image_path,"rb")
detected_faces = client.face.detect_with_stream(image=image_stream)

faces.show_faces(image_path, detected_faces)

# %%
image_path = '../data/vision/store-camera-2.jpg'
image_stream = open(image_path,"rb")
detected_faces = client.face.detect_with_stream(image=image_stream)

faces.show_faces(image_path, detected_faces, show_id=True)

# %%
image_path = '../data/vision/store-camera-2.jpg'
image_stream = open(image_path,"rb")

attributes = ['age', 'emotion']
detected_faces = client.face.detect_with_stream(image = image_stream, return_face_attributes=attributes)
faces.show_face_attributes(image_path,detected_faces)
